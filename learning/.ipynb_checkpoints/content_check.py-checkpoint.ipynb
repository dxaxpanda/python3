# %%
#!/usr/bin/env/python2.7

""" Check website availability with footer content header. 
    As such, for http://www.wincomparator.net will be checked 
    with the page : 'http://www.wincomparator.com/fr-fr/match-en-direct/football/'
    to ensure the arbo is fully available. If not it will try to reload it as a cron 
    job working each minute. """

"""check_url.

Usage: 

    check_url.py [-oh FILE] [-q | -v ] [URL CONTENT]
    check_url.py -h | --help
    check_url.py 
       
   

Arguments:

    URL    url to check
    
    CONTENT content inside the url to check


Options:

    -h,  --help print usage
    
    -v verbose mode
    
    -q quiet mode
    
    -o output file




"""



import urllib2
from docopt import docopt










def Get_url(url):
    """ Check the provided URL and return its response. """
    try:
        resp = urllib2.urlopen(url)
        print resp.info()
        
    except: 
        pass
    
    

    
def main():
    """ Main CLI entrypoint. """
    import commands
    options = docopt(__doc__)
    
    
    Get_url(url)
